# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Getting Location Data

# %% [markdown]
# # Generate Maps for your dataset
#
#
# 1. Extract Neighbourhood information from "Ward" Column
#
# 2. Change Neighborhood Information format in [Property Assessment  Dataset ](https://data.edmonton.ca/City-Administration/Property-Assessment-Data-Current-Calendar-Year-/q7d6-ambg)to match Information in Ward Column
#
# 3. Match and Extract Latitude & Longitude data based on Neighbourhood
#
# 4. Check for Neighbourhoods still missing Location data due to "data validation" errors
#
# 5. Generate Map

# %% [markdown]
# “The Open Geospatial Solutions (opengeos) GitHub organization hosts a collection of open-source geospatial software projects. The projects are developed by a community of geospatial software developers and researchers...”
#
# 𝐓𝐡𝐞𝐢𝐫 𝐜𝐨𝐥𝐥𝐞𝐜𝐭𝐢𝐨𝐧 𝐚𝐬 𝐨𝐟 𝐭𝐨𝐝𝐚𝐲:
#
# 𝐏𝐲𝐭𝐡𝐨𝐧 𝐏𝐚𝐜𝐤𝐚𝐠𝐞𝐬
# - earthformer: https://ow.ly/ZonI50PZm8i
# - geemap: https://ow.ly/AK7x50PZm88
# - geoai: https://ow.ly/64wE50PZm83
# - geospatial: https://ow.ly/1PPM50PZm8h
# - geospatial-ml: https://ow.ly/p9Bf50PZm86
# - leafmap: https://ow.ly/6wJR50PZm8m
# - lidar: https://ow.ly/rxTP50PZm8j
# - mapwidget: https://ow.ly/QfH250PZm7Y
# - open-buildings: https://ow.ly/7L2M50PZm81
# - pygis: https://ow.ly/xtX650PZm8f
# - segment-anything-py: https://ow.ly/mKnM50PZm8c
# - segment-geospatial: https://ow.ly/moZi50PZm7X
# - whitebox-python: https://ow.ly/JF8I50PZm8o
# - whiteboxgui: https://ow.ly/vPyM50PZm82
#
# 𝐃𝐚𝐭𝐚 𝐂𝐚𝐭𝐚𝐥𝐨𝐠𝐬
# - geospatial-data-catalogs: https://ow.ly/ocTO50PZm8p
# - aws-open-data: https://ow.ly/CNQF50PZm8b
# - aws-open-data-geo: https://ow.ly/tIVz50PZm7W
# - aws-open-data-stac: https://ow.ly/i5Ir50PZm8k
# - Earth-Engine-Catalog: https://ow.ly/UW9150PZm8e
# - NASA-CMR-STAC: https://ow.ly/KXOj50PZm8l
# - stac-index-catalogs: https://ow.ly/YQma50PZm85
# - maxar-open-data: https://ow.ly/CI7j50PZm84
# - data: https://ow.ly/3muu50PZm7Z
#
#
#
# 𝐅𝐨𝐫 𝐦𝐨𝐫𝐞, 𝐟𝐨𝐥𝐥𝐨𝐰 𝐭𝐡𝐞𝐦 𝐡𝐞𝐫𝐞: https://ow.ly/sFZf50PZm87

# %% [markdown]
# We will be using Plotly's Open Street Map

# %% [markdown]
# [Plotly Open source Maps](https://plotly.com/python/maps/)

# %%
import pandas as pd
import plotly.express as px

# %% [markdown]
# # Sample Dataset- Bearspaw Chapel Only

# %%
# Create a DataFrame from the data
df = pd.read_csv("/Final_Clean_Data.csv")

# %%
df.head()
# Out:
#    Unnamed: 0              Date              Location              Stake  \
# 0           0  10/17/2023 10:36    Londonderry Chapel  Bonnie Doon Stake
# 1           1  10/17/2023 10:36  Gateway Stake Centre      Gateway Stake
# 2           2  10/17/2023 10:40  Gateway Stake Centre      Gateway Stake
# 3           3  10/17/2023 10:41  Gateway Stake Centre      Gateway Stake
# 4           4  10/17/2023 10:44    Londonderry Chapel  Bonnie Doon Stake
#
#    # of Adult Volunteers  # of Youth Volunteers  Donation Bags Collected  \
# 0                      1                      3                       14
# 1                      3                      1                       18
# 2                      2                      0                       20
# 3                      2                      0                       20
# 4                      1                      0                        2
#
#    Time to Complete (min)  Completed More Than One Route  \
# 0                      25                              0
# 1                      25                              1
# 2                      30                              0
# 3                      25                              1
# 4                       5                              0
#
#             Ward/Branch  Routes Completed  Doors in Route  Time Spent
# 0        Clareview Ward                 1              14    25.00000
# 1  Crawford Plains Ward                 2             144    37.10514
# 2     Silver Berry Ward                 1             186    37.10514
# 3  Crawford Plains Ward                 1               0    30.00000
# 4      Londonderry Ward                 1               1    37.10514

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 502 entries, 0 to 501
# Data columns (total 13 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Unnamed: 0                     502 non-null    int64
#  1   Date                           434 non-null    object
#  2   Location                       502 non-null    object
#  3   Stake                          502 non-null    object
#  4   # of Adult Volunteers          502 non-null    int64
#  5   # of Youth Volunteers          502 non-null    int64
#  6   Donation Bags Collected        502 non-null    int64
#  7   Time to Complete (min)         502 non-null    int64
#  8   Completed More Than One Route  502 non-null    int64
#  9   Ward/Branch                    501 non-null    object
#  10  Routes Completed               502 non-null    int64
#  11  Doors in Route                 502 non-null    int64
#  12  Time Spent                     502 non-null    float64
# dtypes: float64(1), int64(8), object(4)
# memory usage: 51.1+ KB

# %%
df.shape
# Out:
# (502, 13)

# %% [markdown]
# # Missing Location Data
#
# Ideally , you should find the missing data using the property dataset, but for test purposes we will be deleting the missing location data

# %%
# Filter out rows with missing Latitude or Longitude values
#df = df.dropna(subset=['Latitude', 'Longitude'])

# %%
# Set the map style to "open-street-map" and create the map
'''fig = px.scatter_mapbox(df,
                        lat='Latitude',
                        lon='Longitude',
                        hover_name='Drop off location',  # Hover information. You can change this to Neighbourhood.
                        zoom=12)  # Adjust the zoom level as needed'''
# Out:
# "fig = px.scatter_mapbox(df,\n                        lat='Latitude',\n                        lon='Longitude',\n                        hover_name='Drop off location',  # Hover information. You can change this to Neighbourhood.\n                        zoom=12)  # Adjust the zoom level as needed"

# %%
# Update map layout to use OpenStreetMap style
#fig.update_layout(mapbox_style='open-street-map')

# %%
# Show the map
#fig.show()

# %%
# Load the dataset
data = pd.read_csv('/Final_Clean_Data.csv')

# %%
data.head()
# Out:
#    Unnamed: 0              Date              Location              Stake  \
# 0           0  10/17/2023 10:36    Londonderry Chapel  Bonnie Doon Stake
# 1           1  10/17/2023 10:36  Gateway Stake Centre      Gateway Stake
# 2           2  10/17/2023 10:40  Gateway Stake Centre      Gateway Stake
# 3           3  10/17/2023 10:41  Gateway Stake Centre      Gateway Stake
# 4           4  10/17/2023 10:44    Londonderry Chapel  Bonnie Doon Stake
#
#    # of Adult Volunteers  # of Youth Volunteers  Donation Bags Collected  \
# 0                      1                      3                       14
# 1                      3                      1                       18
# 2                      2                      0                       20
# 3                      2                      0                       20
# 4                      1                      0                        2
#
#    Time to Complete (min)  Completed More Than One Route  \
# 0                      25                              0
# 1                      25                              1
# 2                      30                              0
# 3                      25                              1
# 4                       5                              0
#
#             Ward/Branch  Routes Completed  Doors in Route  Time Spent
# 0        Clareview Ward                 1              14    25.00000
# 1  Crawford Plains Ward                 2             144    37.10514
# 2     Silver Berry Ward                 1             186    37.10514
# 3  Crawford Plains Ward                 1               0    30.00000
# 4      Londonderry Ward                 1               1    37.10514

# %%
data["Ward/Branch"].isnull().sum()
# Out:
# 0

# %%
data.dtypes
# Out:
# Unnamed: 0                         int64
# Date                              object
# Location                          object
# Stake                             object
# # of Adult Volunteers              int64
# # of Youth Volunteers              int64
# Donation Bags Collected            int64
# Time to Complete (min)             int64
# Completed More Than One Route      int64
# Ward/Branch                       object
# Routes Completed                   int64
# Doors in Route                     int64
# Time Spent                       float64
# dtype: object

# %%
data.shape
# Out:
# (502, 13)

# %%
# Out:
# Unnamed: 0                        0
# Date                             68
# Location                          0
# Stake                             0
# # of Adult Volunteers             0
# # of Youth Volunteers             0
# Donation Bags Collected           0
# Time to Complete (min)            0
# Completed More Than One Route     0
# Ward/Branch                       0
# Routes Completed                  0
# Doors in Route                    0
# Time Spent                        0
# dtype: int64

# %%
#Extract neighbourhood from the 'Ward/Branch' column
data['Neighbourhood'] = data['Ward/Branch'].apply(lambda x: ''.join(x.split()[:-1]))
#In this code, the split() function splits the 'Ward' column by space, and [:-1] extracts all parts except the last one (in this case, it removes 'Ward'). Then, ' '.join() combines the remaining parts back into a string. The results will be stored in the new 'Neighbourhood' column in your DataFrame


data.head()
# Out:
#    Unnamed: 0              Date              Location              Stake  \
# 0           0  10/17/2023 10:36    Londonderry Chapel  Bonnie Doon Stake
# 1           1  10/17/2023 10:36  Gateway Stake Centre      Gateway Stake
# 2           2  10/17/2023 10:40  Gateway Stake Centre      Gateway Stake
# 3           3  10/17/2023 10:41  Gateway Stake Centre      Gateway Stake
# 4           4  10/17/2023 10:44    Londonderry Chapel  Bonnie Doon Stake
#
#    # of Adult Volunteers  # of Youth Volunteers  Donation Bags Collected  \
# 0                      1                      3                       14
# 1                      3                      1                       18
# 2                      2                      0                       20
# 3                      2                      0                       20
# 4                      1                      0                        2
#
#    Time to Complete (min)  Completed More Than One Route  \
# 0                      25                              0
# 1                      25                              1
# 2                      30                              0
# 3                      25                              1
# 4                       5                              0
#
#             Ward/Branch  Routes Completed  Doors in Route  Time Spent  \
# 0        Clareview Ward                 1              14    25.00000
# 1  Crawford Plains Ward                 2             144    37.10514
# 2     Silver Berry Ward                 1             186    37.10514
# 3  Crawford Plains Ward                 1               0    30.00000
# 4      Londonderry Ward                 1               1    37.10514
#
#     Neighbourhood
# 0       Clareview
# 1  CrawfordPlains
# 2     SilverBerry
# 3  CrawfordPlains
# 4     Londonderry

# %%
data.nunique()
# Out:
# Unnamed: 0                       502
# Date                             170
# Location                           9
# Stake                              6
# # of Adult Volunteers             14
# # of Youth Volunteers             48
# Donation Bags Collected           86
# Time to Complete (min)           104
# Completed More Than One Route      2
# Ward/Branch                       26
# Routes Completed                   4
# Doors in Route                   197
# Time Spent                       106
# Neighbourhood                     26
# dtype: int64

# %%
# Load the Property dataset
property_data = pd.read_csv('/Property_Assessment_Data__Current_Calendar_Year__20231024 (1).csv')

# %%
property_data.head()
# Out:
#    Account Number Suite  House Number    Street Name Garage  Neighbourhood ID  \
# 0         3755261   NaN           NaN            NaN      N            2560.0
# 1         3925286   NaN           NaN            NaN      N            2311.0
# 2         1194919   NaN       15923.0  88A AVENUE NW      Y            4310.0
# 3         1034339   NaN        9420.0   92 STREET NW      N            6710.0
# 4         1115203   NaN         603.0  199 STREET NW      N            4463.0
#
#      Neighbourhood                Ward  Assessed Value   Latitude   Longitude  \
# 0           NEWTON          Métis Ward             500  53.570507 -113.427876
# 1           GORMAN           Dene Ward          150500  53.617825 -113.393407
# 2  MEADOWLARK PARK  sipiwiyiniwak Ward          384500  53.522292 -113.597530
# 3       STRATHEARN          Métis Ward        47030000  53.530949 -113.469279
# 4   RIVERVIEW AREA  sipiwiyiniwak Ward           11000  53.436979 -113.663444
#
#                                   Point Location  Assessment Class % 1  \
# 0   POINT (-113.42787626991075 53.5705074742781)                   100
# 1  POINT (-113.39340667965742 53.61782538629719)                   100
# 2   POINT (-113.59753002952249 53.5222918203277)                   100
# 3  POINT (-113.46927857387664 53.53094866121484)                   100
# 4  POINT (-113.66344400662132 53.43697906291636)                   100
#
#    Assessment Class % 2  Assessment Class % 3 Assessment Class 1  \
# 0                   NaN                   NaN         COMMERCIAL
# 1                   NaN                   NaN         COMMERCIAL
# 2                   NaN                   NaN        RESIDENTIAL
# 3                   NaN                   NaN  OTHER RESIDENTIAL
# 4                   NaN                   NaN         COMMERCIAL
#
#   Assessment Class 2 Assessment Class 3
# 0                NaN                NaN
# 1                NaN                NaN
# 2                NaN                NaN
# 3                NaN                NaN
# 4                NaN                NaN

# %% [markdown]
# # Data Validation

# %%
#add index manually and upload agian and merge that data

# %%
# Convert 'Neighbourhood' column in the first dataset to sentence case
property_data['Neighbourhood'] = property_data['Neighbourhood'].str.title()

# %%
property_data.shape
# Out:
# (422160, 18)

# %%
property_data.head()
# Out:
#    Account Number Suite  House Number    Street Name Garage  Neighbourhood ID  \
# 0         3755261   NaN           NaN            NaN      N            2560.0
# 1         3925286   NaN           NaN            NaN      N            2311.0
# 2         1194919   NaN       15923.0  88A AVENUE NW      Y            4310.0
# 3         1034339   NaN        9420.0   92 STREET NW      N            6710.0
# 4         1115203   NaN         603.0  199 STREET NW      N            4463.0
#
#      Neighbourhood                Ward  Assessed Value   Latitude   Longitude  \
# 0           Newton          Métis Ward             500  53.570507 -113.427876
# 1           Gorman           Dene Ward          150500  53.617825 -113.393407
# 2  Meadowlark Park  sipiwiyiniwak Ward          384500  53.522292 -113.597530
# 3       Strathearn          Métis Ward        47030000  53.530949 -113.469279
# 4   Riverview Area  sipiwiyiniwak Ward           11000  53.436979 -113.663444
#
#                                   Point Location  Assessment Class % 1  \
# 0   POINT (-113.42787626991075 53.5705074742781)                   100
# 1  POINT (-113.39340667965742 53.61782538629719)                   100
# 2   POINT (-113.59753002952249 53.5222918203277)                   100
# 3  POINT (-113.46927857387664 53.53094866121484)                   100
# 4  POINT (-113.66344400662132 53.43697906291636)                   100
#
#    Assessment Class % 2  Assessment Class % 3 Assessment Class 1  \
# 0                   NaN                   NaN         COMMERCIAL
# 1                   NaN                   NaN         COMMERCIAL
# 2                   NaN                   NaN        RESIDENTIAL
# 3                   NaN                   NaN  OTHER RESIDENTIAL
# 4                   NaN                   NaN         COMMERCIAL
#
#   Assessment Class 2 Assessment Class 3
# 0                NaN                NaN
# 1                NaN                NaN
# 2                NaN                NaN
# 3                NaN                NaN
# 4                NaN                NaN

# %%
# Merge the two dataframes on the Neighbourhood column
# Use how="left" to keep all the rows from the initial dataset "data"
# Use suffixes to distinguish the columns from each dataframe
merged = pd.merge(data, property_data, on="Neighbourhood", how="left", suffixes=("_data", "_property_data"))
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 279000 entries, 0 to 278999
# Data columns (total 31 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Unnamed: 0                     279000 non-null  int64
#  1   Date                           278932 non-null  object
#  2   Location                       279000 non-null  object
#  3   Stake                          279000 non-null  object
#  4   # of Adult Volunteers          279000 non-null  int64
#  5   # of Youth Volunteers          279000 non-null  int64
#  6   Donation Bags Collected        279000 non-null  int64
#  7   Time to Complete (min)         279000 non-null  int64
#  8   Completed More Than One Route  279000 non-null  int64
#  9   Ward/Branch                    279000 non-null  object
#  10  Routes Completed               279000 non-null  int64
#  11  Doors in Route                 279000 non-null  int64
#  12  Time Spent                     279000 non-null  float64
#  13  Neighbourhood                  279000 non-null  object
#  14  Account Number                 278593 non-null  float64
#  15  Suite                          79636 non-null   object
#  16  House Number                   234516 non-null  float64
#  17  Street Name                    234516 non-null  object
#  18  Garage                         278593 non-null  object
#  19  Neighbourhood ID               278593 non-null  float64
#  20  Ward                           278593 non-null  object
#  21  Assessed Value                 278593 non-null  float64
#  22  Latitude                       278593 non-null  float64
#  23  Longitude                      278593 non-null  float64
#  24  Point Location                 278593 non-null  object
#  25  Assessment Class % 1           278593 non-null  float64
#  26  Assessment Class % 2           194 non-null     float64
#  27  Assessment Class % 3           0 non-null       float64
#  28  Assessment Class 1             278593 non-null  object
#  29  Assessment Class 2             194 non-null     object
#  30  Assessment Class 3             0 non-null       object
# dtypes: float64(10), int64(8), object(13)
# memory usage: 68.1+ MB

# %%
merged.shape
# Out:
# (279000, 31)

# %%
merged.head()
#A  lot of duplication
# Out:
#    Unnamed: 0              Date              Location              Stake  \
# 0           0  10/17/2023 10:36    Londonderry Chapel  Bonnie Doon Stake
# 1           1  10/17/2023 10:36  Gateway Stake Centre      Gateway Stake
# 2           2  10/17/2023 10:40  Gateway Stake Centre      Gateway Stake
# 3           3  10/17/2023 10:41  Gateway Stake Centre      Gateway Stake
# 4           4  10/17/2023 10:44    Londonderry Chapel  Bonnie Doon Stake
#
#    # of Adult Volunteers  # of Youth Volunteers  Donation Bags Collected  \
# 0                      1                      3                       14
# 1                      3                      1                       18
# 2                      2                      0                       20
# 3                      2                      0                       20
# 4                      1                      0                        2
#
#    Time to Complete (min)  Completed More Than One Route  \
# 0                      25                              0
# 1                      25                              1
# 2                      30                              0
# 3                      25                              1
# 4                       5                              0
#
#             Ward/Branch  ...  Assessed Value  Latitude  Longitude  \
# 0        Clareview Ward  ...             NaN       NaN        NaN
# 1  Crawford Plains Ward  ...             NaN       NaN        NaN
# 2     Silver Berry Ward  ...             NaN       NaN        NaN
# 3  Crawford Plains Ward  ...             NaN       NaN        NaN
# 4      Londonderry Ward  ...             NaN       NaN        NaN
#
#   Point Location  Assessment Class % 1 Assessment Class % 2  \
# 0            NaN                   NaN                  NaN
# 1            NaN                   NaN                  NaN
# 2            NaN                   NaN                  NaN
# 3            NaN                   NaN                  NaN
# 4            NaN                   NaN                  NaN
#
#    Assessment Class % 3 Assessment Class 1 Assessment Class 2  \
# 0                   NaN                NaN                NaN
# 1                   NaN                NaN                NaN
# 2                   NaN                NaN                NaN
# 3                   NaN                NaN                NaN
# 4                   NaN                NaN                NaN
#
#    Assessment Class 3
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
#
# [5 rows x 31 columns]

# %%
merged.tail()
# Out:
#         Unnamed: 0 Date                Location           Stake  \
# 278995         497  NaN  Coronation Park Chapel  North Edmonton
# 278996         498  NaN  Coronation Park Chapel  North Edmonton
# 278997         499  NaN  Coronation Park Chapel  North Edmonton
# 278998         500  NaN  Coronation Park Chapel  North Edmonton
# 278999         501  NaN  Coronation Park Chapel  North Edmonton
#
#         # of Adult Volunteers  # of Youth Volunteers  Donation Bags Collected  \
# 278995                      0                     43                       60
# 278996                      3                     38                      150
# 278997                      1                     38                       45
# 278998                      1                     30                       60
# 278999                      3                     19                       75
#
#         Time to Complete (min)  Completed More Than One Route  \
# 278995                     293                              0
# 278996                     305                              0
# 278997                     299                              0
# 278998                     273                              0
# 278999                     281                              0
#
#                  Ward/Branch  ...  Assessed Value  Latitude  Longitude  \
# 278995  Coronation Park Ward  ...             NaN       NaN        NaN
# 278996  Coronation Park Ward  ...             NaN       NaN        NaN
# 278997  Coronation Park Ward  ...             NaN       NaN        NaN
# 278998  Coronation Park Ward  ...             NaN       NaN        NaN
# 278999  Coronation Park Ward  ...             NaN       NaN        NaN
#
#        Point Location  Assessment Class % 1 Assessment Class % 2  \
# 278995            NaN                   NaN                  NaN
# 278996            NaN                   NaN                  NaN
# 278997            NaN                   NaN                  NaN
# 278998            NaN                   NaN                  NaN
# 278999            NaN                   NaN                  NaN
#
#         Assessment Class % 3 Assessment Class 1 Assessment Class 2  \
# 278995                   NaN                NaN                NaN
# 278996                   NaN                NaN                NaN
# 278997                   NaN                NaN                NaN
# 278998                   NaN                NaN                NaN
# 278999                   NaN                NaN                NaN
#
#         Assessment Class 3
# 278995                 NaN
# 278996                 NaN
# 278997                 NaN
# 278998                 NaN
# 278999                 NaN
#
# [5 rows x 31 columns]

# %%
merged.nunique()
# Out:
# Unnamed: 0                         502
# Date                               170
# Location                             9
# Stake                                6
# # of Adult Volunteers               14
# # of Youth Volunteers               48
# Donation Bags Collected             86
# Time to Complete (min)             104
# Completed More Than One Route        2
# Ward/Branch                         26
# Routes Completed                     4
# Doors in Route                     197
# Time Spent                         106
# Neighbourhood                       26
# Account Number                   12221
# Suite                              398
# House Number                      3620
# Street Name                        175
# Garage                               2
# Neighbourhood ID                     4
# Ward                                 4
# Assessed Value                    1454
# Latitude                          6649
# Longitude                         6649
# Point Location                    6649
# Assessment Class % 1                 7
# Assessment Class % 2                 6
# Assessment Class % 3                 0
# Assessment Class 1                   3
# Assessment Class 2                   2
# Assessment Class 3                   0
# dtype: int64

# %% [markdown]
# # Add a unique identifier to data to enable us delete all duplicates

# %%
# assign a unique ID to each group of identical rows
data['ID'] = data.groupby(data.columns.tolist(), sort=False).ngroup() + 1
data.head()
# Out:
#    Unnamed: 0              Date              Location              Stake  \
# 0           0  10/17/2023 10:36    Londonderry Chapel  Bonnie Doon Stake
# 1           1  10/17/2023 10:36  Gateway Stake Centre      Gateway Stake
# 2           2  10/17/2023 10:40  Gateway Stake Centre      Gateway Stake
# 3           3  10/17/2023 10:41  Gateway Stake Centre      Gateway Stake
# 4           4  10/17/2023 10:44    Londonderry Chapel  Bonnie Doon Stake
#
#    # of Adult Volunteers  # of Youth Volunteers  Donation Bags Collected  \
# 0                      1                      3                       14
# 1                      3                      1                       18
# 2                      2                      0                       20
# 3                      2                      0                       20
# 4                      1                      0                        2
#
#    Time to Complete (min)  Completed More Than One Route  \
# 0                      25                              0
# 1                      25                              1
# 2                      30                              0
# 3                      25                              1
# 4                       5                              0
#
#             Ward/Branch  Routes Completed  Doors in Route  Time Spent  \
# 0        Clareview Ward                 1              14    25.00000
# 1  Crawford Plains Ward                 2             144    37.10514
# 2     Silver Berry Ward                 1             186    37.10514
# 3  Crawford Plains Ward                 1               0    30.00000
# 4      Londonderry Ward                 1               1    37.10514
#
#     Neighbourhood   ID
# 0       Clareview  1.0
# 1  CrawfordPlains  2.0
# 2     SilverBerry  3.0
# 3  CrawfordPlains  4.0
# 4     Londonderry  5.0

# %%
# Merge the tables on the 'Neighbourhood' column
# Perform an inner join on 'Neighbourhood' column
merged_data = pd.merge(data, property_data[['Neighbourhood', 'Latitude', 'Longitude']], on='Neighbourhood', how='inner')

merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 278593 entries, 0 to 278592
# Data columns (total 17 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Unnamed: 0                     278593 non-null  int64
#  1   Date                           278593 non-null  object
#  2   Location                       278593 non-null  object
#  3   Stake                          278593 non-null  object
#  4   # of Adult Volunteers          278593 non-null  int64
#  5   # of Youth Volunteers          278593 non-null  int64
#  6   Donation Bags Collected        278593 non-null  int64
#  7   Time to Complete (min)         278593 non-null  int64
#  8   Completed More Than One Route  278593 non-null  int64
#  9   Ward/Branch                    278593 non-null  object
#  10  Routes Completed               278593 non-null  int64
#  11  Doors in Route                 278593 non-null  int64
#  12  Time Spent                     278593 non-null  float64
#  13  Neighbourhood                  278593 non-null  object
#  14  ID                             278593 non-null  float64
#  15  Latitude                       278593 non-null  float64
#  16  Longitude                      278593 non-null  float64
# dtypes: float64(4), int64(8), object(5)
# memory usage: 38.3+ MB

# %%
merged.shape

# %%
# delete duplicates based on the unique identifier- "ID"
merged_data = merged_data.drop_duplicates(subset='ID')
merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 95 entries, 0 to 273079
# Data columns (total 17 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Unnamed: 0                     95 non-null     int64
#  1   Date                           95 non-null     object
#  2   Location                       95 non-null     object
#  3   Stake                          95 non-null     object
#  4   # of Adult Volunteers          95 non-null     int64
#  5   # of Youth Volunteers          95 non-null     int64
#  6   Donation Bags Collected        95 non-null     int64
#  7   Time to Complete (min)         95 non-null     int64
#  8   Completed More Than One Route  95 non-null     int64
#  9   Ward/Branch                    95 non-null     object
#  10  Routes Completed               95 non-null     int64
#  11  Doors in Route                 95 non-null     int64
#  12  Time Spent                     95 non-null     float64
#  13  Neighbourhood                  95 non-null     object
#  14  ID                             95 non-null     float64
#  15  Latitude                       95 non-null     float64
#  16  Longitude                      95 non-null     float64
# dtypes: float64(4), int64(8), object(5)
# memory usage: 13.4+ KB

# %% [markdown]
# # Download Dataset

# %%
merged_data.to_csv('merged_data.csv', index=False)

# %%
merged_data.shape
# Out:
# (95, 17)

# %% [markdown]
# # ALTERNATIVELY,
#
# Drop irrelevant columns in property dataset except Latitude & Longitude by index (20 &21)

# %%
#merged.info()

# %%
#merged = merged.drop(merged.columns[[12,13,14,15,16,17,18,22,23,24,25,26,27,28]], axis=1)
#merged.nunique()

# %%
#merged

# %% [markdown]
# NOte that with this method we still have 480 unique IDs of which some may have missing values (See Longitude & Latitude Columns) that can be updated manually.

# %%
#merged = merged.drop["Unnamed: 0"]

# %%
#duplicates = merged[merged.duplicated()]
#duplicates

# %%
#merged.info()

# %%
# delete duplicates based on the unique identifier- "ID"
#merged = merged.drop_duplicates(subset='Neighbourhood ID')
#merged.info()

# %%
#merged.shape

# %% [markdown]
# # Download the Datasets.

# %%
merged.to_csv('merged.csv', index=False)

# %%
property_data.to_csv('Property_data.csv', index=False)

# %%
data.to_csv('Updated_neighbourhood_data.csv', index=False)

# %% [markdown]
# # Manual Updates
#
# Notice that Belmead is missing Neighbourhood Information.
# Refer to the Additional Dataset in Norquest REPO and update the neighbourhood info accordingly.
#
# Also update the Location Data (Longitude & Latitude only) based on Neighbourhood info

# %% [markdown]
# Upload Updated Data

# %%
# Load the dataset
Location_data_updated = pd.read_csv('/content/merged_data.csv')

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
Location_data_updated.head()
# Out:
#    Unnamed: 0              Date            Location                 Stake  \
# 0          33  10/17/2023 11:09  North Stake Centre  Edmonton North Stake
# 1          35  10/17/2023 11:09  North Stake Centre  Edmonton North Stake
# 2          39  10/17/2023 11:11  North Stake Centre  Edmonton North Stake
# 3          43  10/17/2023 11:12  North Stake Centre  Edmonton North Stake
# 4          57  10/17/2023 11:20  North Stake Centre  Edmonton North Stake
#
#    # of Adult Volunteers  # of Youth Volunteers  Donation Bags Collected  \
# 0                      2                      1                       21
# 1                      1                      1                       23
# 2                      2                      3                       29
# 3                      2                      2                       24
# 4                      2                      3                       35
#
#    Time to Complete (min)  Completed More Than One Route     Ward/Branch  \
# 0                      45                              0  Griesbach Ward
# 1                      45                              0  Griesbach Ward
# 2                      60                              0  Griesbach Ward
# 3                      30                              0  Griesbach Ward
# 4                      70                              0  Griesbach Ward
#
#    Routes Completed  Doors in Route  Time Spent Neighbourhood    ID  \
# 0                 1             206        45.0     Griesbach  34.0
# 1                 1             206        45.0     Griesbach  36.0
# 2                 1             107        60.0     Griesbach  40.0
# 3                 1              20        30.0     Griesbach  44.0
# 4                 1             370        65.0     Griesbach  58.0
#
#     Latitude   Longitude
# 0  53.613468 -113.515751
# 1  53.613468 -113.515751
# 2  53.613468 -113.515751
# 3  53.613468 -113.515751
# 4  53.613468 -113.515751

# %%
# Filter out rows with missing Latitude or Longitude values
Location_data_updated = Location_data_updated.dropna(subset=['Latitude', 'Longitude'])

# %%
Location_data_updated.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95 entries, 0 to 94
# Data columns (total 17 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Unnamed: 0                     95 non-null     int64
#  1   Date                           95 non-null     object
#  2   Location                       95 non-null     object
#  3   Stake                          95 non-null     object
#  4   # of Adult Volunteers          95 non-null     int64
#  5   # of Youth Volunteers          95 non-null     int64
#  6   Donation Bags Collected        95 non-null     int64
#  7   Time to Complete (min)         95 non-null     int64
#  8   Completed More Than One Route  95 non-null     int64
#  9   Ward/Branch                    95 non-null     object
#  10  Routes Completed               95 non-null     int64
#  11  Doors in Route                 95 non-null     int64
#  12  Time Spent                     95 non-null     float64
#  13  Neighbourhood                  95 non-null     object
#  14  ID                             95 non-null     float64
#  15  Latitude                       95 non-null     float64
#  16  Longitude                      95 non-null     float64
# dtypes: float64(4), int64(8), object(5)
# memory usage: 12.7+ KB

# %%
import plotly.express as px
# Set the map style to "open-street-map" and create the map
fig = px.scatter_mapbox(Location_data_updated,
                        lat='Latitude',
                        lon='Longitude',
                        hover_name='Neighbourhood',  # Hover information
                        zoom=12)  # Adjust the zoom level as needed

# %%
# Update map layout to use OpenStreetMap style
fig.update_layout(mapbox_style='open-street-map')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="0e0291fd-8f80-40f0-8d0d-c7787fabf08f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0e0291fd-8f80-40f0-8d0d-c7787fabf08f")) {                    Plotly.newPlot(                        "0e0291fd-8f80-40f0-8d0d-c7787fabf08f",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eLatitude=%{lat}\u003cbr\u003eLongitude=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Griesbach","Griesbach","Griesbach","Griesbach","Griesbach","Griesbach","Griesbach","Griesbach","Griesbach","Griesbach","Griesbach","Griesbach","Griesbach","Griesbach","Griesbach","Griesbach","Griesbach","Griesbach","Griesbach","Griesbach","Griesbach","Griesbach","Griesbach","Griesbach","Griesbach","Griesbach","Griesbach","Griesbach","Griesbach","Griesbach","Griesbach","Griesbach","Griesbach","Greenfield","Greenfield","Greenfield","Greenfield","Greenfield","Greenfield","Greenfield","Greenfield","Greenfield","Greenfield","Greenfield","Greenfield","Greenfield","Greenfield","Greenfield","Ellerslie","Ellerslie","Ellerslie","Ellerslie","Ellerslie","Ellerslie","Ellerslie","Ellerslie","Ellerslie","Ellerslie","Ellerslie","Ellerslie","Ellerslie","Ellerslie","Ellerslie","Ellerslie","Ellerslie","Ellerslie","Ellerslie","Ellerslie","Ellerslie","Ellerslie","Ellerslie","Ellerslie","Ellerslie","Ellerslie","Ellerslie","Ellerslie","Ellerslie","Ellerslie","Ellerslie","Rutherford","Rutherford","Rutherford","Rutherford","Rutherford","Rutherford","Rutherford","Rutherford","Rutherford","Rutherford","Rutherford","Rutherford","Rutherford","Rutherford","Rutherford","Rutherford"],"lat":[53.61346820073056,53.61346820073056,53.61346820073056,53.61346820073056,53.61346820073056,53.61346820073056,53.61346820073056,53.61346820073056,53.61346820073056,53.61346820073056,53.61346820073056,53.61346820073056,53.61346820073056,53.61346820073056,53.61346820073056,53.61346820073056,53.61346820073056,53.61346820073056,53.61346820073056,53.61346820073056,53.61346820073056,53.61346820073056,53.61346820073056,53.61346820073056,53.61346820073056,53.61346820073056,53.61346820073056,53.61346820073056,53.61346820073056,53.61346820073056,53.61346820073056,53.61346820073056,53.61346820073056,53.47604788429193,53.47604788429193,53.47604788429193,53.47604788429193,53.47604788429193,53.47604788429193,53.47604788429193,53.47604788429193,53.47604788429193,53.47604788429193,53.47604788429193,53.47604788429193,53.47604788429193,53.47604788429193,53.47604788429193,53.42974398563295,53.42974398563295,53.42974398563295,53.42974398563295,53.42974398563295,53.42974398563295,53.42974398563295,53.42974398563295,53.42974398563295,53.42974398563295,53.42974398563295,53.42974398563295,53.42974398563295,53.42974398563295,53.42974398563295,53.42974398563295,53.42974398563295,53.42974398563295,53.42974398563295,53.42974398563295,53.42974398563295,53.42974398563295,53.42974398563295,53.42974398563295,53.42974398563295,53.42974398563295,53.42974398563295,53.42974398563295,53.42974398563295,53.42974398563295,53.42974398563295,53.42045712828527,53.42045712828527,53.42045712828527,53.42045712828527,53.42045712828527,53.42045712828527,53.42045712828527,53.42045712828527,53.42045712828527,53.42045712828527,53.42045712828527,53.42045712828527,53.42045712828527,53.42045712828527,53.42045712828527,53.42045712828527],"legendgroup":"","lon":[-113.51575070317364,-113.51575070317364,-113.51575070317364,-113.51575070317364,-113.51575070317364,-113.51575070317364,-113.51575070317364,-113.51575070317364,-113.51575070317364,-113.51575070317364,-113.51575070317364,-113.51575070317364,-113.51575070317364,-113.51575070317364,-113.51575070317364,-113.51575070317364,-113.5157507 ...

# %%
# Show the map
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="4af72fb8-3344-413a-96d8-f1f76fa1da01" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4af72fb8-3344-413a-96d8-f1f76fa1da01")) {                    Plotly.newPlot(                        "4af72fb8-3344-413a-96d8-f1f76fa1da01",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eLatitude=%{lat}\u003cbr\u003eLongitude=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Griesbach","Griesbach","Griesbach","Griesbach","Griesbach","Griesbach","Griesbach","Griesbach","Griesbach","Griesbach","Griesbach","Griesbach","Griesbach","Griesbach","Griesbach","Griesbach","Griesbach","Griesbach","Griesbach","Griesbach","Griesbach","Griesbach","Griesbach","Griesbach","Griesbach","Griesbach","Griesbach","Griesbach","Griesbach","Griesbach","Griesbach","Griesbach","Griesbach","Greenfield","Greenfield","Greenfield","Greenfield","Greenfield","Greenfield","Greenfield","Greenfield","Greenfield","Greenfield","Greenfield","Greenfield","Greenfield","Greenfield","Greenfield","Ellerslie","Ellerslie","Ellerslie","Ellerslie","Ellerslie","Ellerslie","Ellerslie","Ellerslie","Ellerslie","Ellerslie","Ellerslie","Ellerslie","Ellerslie","Ellerslie","Ellerslie","Ellerslie","Ellerslie","Ellerslie","Ellerslie","Ellerslie","Ellerslie","Ellerslie","Ellerslie","Ellerslie","Ellerslie","Ellerslie","Ellerslie","Ellerslie","Ellerslie","Ellerslie","Ellerslie","Rutherford","Rutherford","Rutherford","Rutherford","Rutherford","Rutherford","Rutherford","Rutherford","Rutherford","Rutherford","Rutherford","Rutherford","Rutherford","Rutherford","Rutherford","Rutherford"],"lat":[53.61346820073056,53.61346820073056,53.61346820073056,53.61346820073056,53.61346820073056,53.61346820073056,53.61346820073056,53.61346820073056,53.61346820073056,53.61346820073056,53.61346820073056,53.61346820073056,53.61346820073056,53.61346820073056,53.61346820073056,53.61346820073056,53.61346820073056,53.61346820073056,53.61346820073056,53.61346820073056,53.61346820073056,53.61346820073056,53.61346820073056,53.61346820073056,53.61346820073056,53.61346820073056,53.61346820073056,53.61346820073056,53.61346820073056,53.61346820073056,53.61346820073056,53.61346820073056,53.61346820073056,53.47604788429193,53.47604788429193,53.47604788429193,53.47604788429193,53.47604788429193,53.47604788429193,53.47604788429193,53.47604788429193,53.47604788429193,53.47604788429193,53.47604788429193,53.47604788429193,53.47604788429193,53.47604788429193,53.47604788429193,53.42974398563295,53.42974398563295,53.42974398563295,53.42974398563295,53.42974398563295,53.42974398563295,53.42974398563295,53.42974398563295,53.42974398563295,53.42974398563295,53.42974398563295,53.42974398563295,53.42974398563295,53.42974398563295,53.42974398563295,53.42974398563295,53.42974398563295,53.42974398563295,53.42974398563295,53.42974398563295,53.42974398563295,53.42974398563295,53.42974398563295,53.42974398563295,53.42974398563295,53.42974398563295,53.42974398563295,53.42974398563295,53.42974398563295,53.42974398563295,53.42974398563295,53.42045712828527,53.42045712828527,53.42045712828527,53.42045712828527,53.42045712828527,53.42045712828527,53.42045712828527,53.42045712828527,53.42045712828527,53.42045712828527,53.42045712828527,53.42045712828527,53.42045712828527,53.42045712828527,53.42045712828527,53.42045712828527],"legendgroup":"","lon":[-113.51575070317364,-113.51575070317364,-113.51575070317364,-113.51575070317364,-113.51575070317364,-113.51575070317364,-113.51575070317364,-113.51575070317364,-113.51575070317364,-113.51575070317364,-113.51575070317364,-113.51575070317364,-113.51575070317364,-113.51575070317364,-113.51575070317364,-113.51575070317364,-113.5157507 ...

# %% [markdown]
# To enable the user to input a neighborhood and generate the map dynamically

# %%
def generate_map(neighbourhood):
    # Filter the dataset based on the user input
    filtered_data = Location_data_updated[Location_data_updated['Neighbourhood'] == neighbourhood]

    # Check if the filtered data is empty, if so, return a message indicating no data found
    if filtered_data.empty:
        return "No data found for the specified neighborhood."

    # Create the map using the filtered data
    fig = px.scatter_mapbox(filtered_data,
                            lat='Latitude',
                            lon='Longitude',
                            hover_name='Drop off location',
                            zoom=12)

    # Update map layout to use OpenStreetMap style
    fig.update_layout(mapbox_style='open-street-map')

    # Show the map
    fig.show()

# Example usage:
user_neighbourhood = input("Enter the neighborhood: ")
generate_map(user_neighbourhood)

# %% [markdown]
# # Interview Readiness Questions

# %% [markdown]
# Given a large dataset, how would you optimize the process of merging and cleaning data to improve performance?
#
#
# *   By using code to find missing value and duplicates
# *   Understanding the type of data.
# *   we can either mix the data then fix it or fix the data then mix when we are combining the data
# *   we can fill information by imputation.
# *   then  we will look for more mikstakes like format is same or not
#
#
# Discuss the considerations and challenges involved in integrating data from diverse sources with varying data formats and structures.
#
# *   In case of data there can be mistakes such as wrong numbers or wrong date-time format which can be solved by fixing the format or sometime we have to do it mannually.
# *   Large data: when the data is a lot then it can work slow thus special tool is needed make it work faster.
# *   There are chances where data is need to be transformed like splitting, merging or new variable are created.
#
# How would you handle data inconsistencies and discrepancies when integrating data from multiple sources?
#
#
# *   We can make the data look similar in same format
# *   We have to look for errors in the data like strange number or missing values
# *   data from various sources sometimes not fit the same structure thus they needed to be tranformed to bring into alignment with common structure and to enure there is same format
# *   Make sure to trace back to the original data source and maintiain detailed documatation of the data cleaning and tranformation.
